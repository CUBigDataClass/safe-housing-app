# %% [markdown]
# # Yelp Recommendation System for Housing Project

# %% [markdown]
# ### Setting up the environment for analysis

# %%
#Installing the Necessary packages
# !sudo apt install gdal-bin python-gdal python3-gdal 
# !sudo apt install python3-rtree 
# !pip install git+git://github.com/geopandas/geopandas.git
# !pip install descartes 
# !pip install folium 
# !pip install plotly_express

# %%
#Importing the packages
import pandas as pd 
import numpy as np
import json
import folium
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Exploratory Analysis

# %%
#Reading the Yelp Business DataSet
df = pd.read_csv('yelp_business.csv')
df.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
df.shape
# Out:
# (174567, 13)

# %%
df['Restaurants'] = df['categories'].str.contains('Restaurants')

# %%
df_restaurants = df.loc[df.Restaurants == True]
df_restaurants.head()
# Out:
#                business_id                          name        neighborhood  \
# 4   PfOCPjBrlQAnz__NXj9h_w    "Brick House Tavern + Tap"                 NaN
# 5   o9eMRCWt5PkpLDE0gOPtcQ                     "Messina"                 NaN
# 10  XOSRcvtaKc_Q5H1SAzN20A           "East Coast Coffee"                 NaN
# 14  fNMVV_ZX7CJSDWQGdOM8Nw  "Showmars Government Center"              Uptown
# 15  l09JfMeQ6ynYs5MCJtrcmQ              "Alize Catering"  Yonge and Eglinton
#
#                address            city state postal_code   latitude  \
# 4       "581 Howe Ave"  Cuyahoga Falls    OH       44221  41.119535
# 5     "Richterstr. 11"       Stuttgart    BW       70567  48.727200
# 10  "737 West Pike St"         Houston    PA       15342  40.241548
# 14      "600 E 4th St"       Charlotte    NC       28202  35.221647
# 15     "2459 Yonge St"         Toronto    ON     M4P 2H6  43.711399
#
#     longitude  stars  review_count  is_open  \
# 4  -81.475690    3.5           116        1
# 5    9.147950    4.0             5        1
# 10 -80.212815    4.5             3        0
# 14 -80.839345    3.5             7        1
# 15 -79.399339    3.0            12        0
#
#                                            categories  Restaurants
# 4   American (New);Nightlife;Bars;Sandwiches;Ameri...         True
# 5                                 Italian;Restaurants         True
# 10  Breakfast & Brunch;Gluten-Free;Coffee & Tea;Fo...         True
# 14                 Restaurants;American (Traditional)         True
# 15                         Italian;French;Restaurants         True

# %%
df_restaurants.shape
# Out:
# (54618, 14)

# %% [markdown]
# **Sorting the Restaurants based on review count and Stars**

# %%
top_restaurants = df_restaurants.sort_values(by=['review_count', 'stars'], ascending=False)[:1000]
top_restaurants.head()
# Out:
#                    business_id                   name neighborhood  \
# 97944   4JNXUYY8wbaaDmk3BPzlWw         "Mon Ami Gabi"    The Strip
# 119907  RESDUcs7fIiihp38-d6_6g     "Bacchanal Buffet"    The Strip
# 69993   K7lWdNUhCbcnEvI0NhGewg         "Wicked Spoon"    The Strip
# 81212   cYwJA2A6I12KNkm2rtXd5g  "Gordon Ramsay BurGR"    The Strip
# 139699  DkYS3arLOhA8si5uUEmHOw     "Earl of Sandwich"    The Strip
#
#                         address       city state postal_code   latitude  \
# 97944   "3655 Las Vegas Blvd S"  Las Vegas    NV       89109  36.112827
# 119907  "3570 S Las Vegas Blvd"  Las Vegas    NV       89109  36.116113
# 69993   "3708 Las Vegas Blvd S"  Las Vegas    NV       89109  36.109538
# 81212   "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.110724
# 139699  "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.108228
#
#          longitude  stars  review_count  is_open  \
# 97944  -115.172581    4.0          7361        1
# 119907 -115.176222    4.0          7009        1
# 69993  -115.176170    3.5          5950        1
# 81212  -115.172169    4.0          5447        0
# 139699 -115.171869    4.5          4869        1
#
#                                                categories  Restaurants
# 97944   French;Steakhouses;Restaurants;Breakfast & Brunch         True
# 119907  Sandwiches;Buffets;Restaurants;Breakfast & Bru...         True
# 69993              Buffets;Breakfast & Brunch;Restaurants         True
# 81212          American (Traditional);Burgers;Restaurants         True
# 139699  Caterers;Sandwiches;Restaurants;Food Delivery ...         True

# %% [markdown]
# **Fetching the list of restaurants based on geoloacation**

# %%
coords = top_restaurants[['longitude','latitude']]
distortions = []
K = range(1,100)
for k in K:
    kmeansModel = KMeans(n_clusters=k)
    kmeansModel = kmeansModel.fit(coords)
    distortions.append(kmeansModel.inertia_)

# %% [markdown]
# **Checking the similarity of an object based on silhouette score**

# %%
from sklearn.metrics import silhouette_score

sil = []
kmax = 50

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
  kmeans = KMeans(n_clusters = k).fit(coords)
  labels = kmeans.labels_
  sil.append(silhouette_score(coords, labels, metric = 'euclidean'))

# %%
sil
# Out:
# [0.9280106074771384,
#  0.9549353006689872,
#  0.9241468512709209,
#  0.9410237244104829,
#  0.9494674213690556,
#  0.9611599180508569,
#  0.973228489090511,
#  0.9752910524926574,
#  0.8103502151194059,
#  0.8215885175108103,
#  0.57065009753802,
#  0.6087281226710416,
#  0.6123992507899004,
#  0.6369912152290201,
#  0.5524801629814051,
#  0.5932136113941352,
#  0.5753631256553565,
#  0.5969900487645492,
#  0.5823279457264768,
#  0.5873245966433382,
#  0.5815486783822276,
#  0.5864701717780808,
#  0.5671254897200971,
#  0.5641533838727175,
#  0.5700177979125347,
#  0.5777714490318743,
#  0.5624071144525077,
#  0.568939307843564,
#  0.5539308176939606,
#  0.5651948551908165,
#  0.5734727362463077,
#  0.5533930686887076,
#  0.5732193425556136,
#  0.5101455318217397,
#  0.5704017180937863,
#  0.5101663214907106,
#  0.5345417274136737,
#  0.5170955918090501,
#  0.5172408979037577,
#  0.5008545146031212,
#  0.5062447630276455,
#  0.5075198332715339,
#  0.5213249623561714,
#  0.4965582146525742,
#  0.5024941766638498,
#  0.5189983138070283,
#  0.5135652573842,
#  0.554427555923691,
#  0.5398129976976952]

# %% [markdown]
# **Fitting K-Means model on the data**

# %%
kmeans = KMeans(n_clusters=5, init='k-means++')
kmeans.fit(coords)
y = kmeans.labels
print("k = 5", " silhouette_score ", silhouette_score(coords, y, metric='euclidean'))
# Out:
# k = 5  silhouette_score  0.9410237244104829

# %% [markdown]
# **Prediction based on location**

# %%
top_restaurants['cluster'] = kmeans.predict(top_restaurants[['longitude','latitude']])
top_restaurants.head()
# Out:
#                    business_id                   name neighborhood  \
# 97944   4JNXUYY8wbaaDmk3BPzlWw         "Mon Ami Gabi"    The Strip
# 119907  RESDUcs7fIiihp38-d6_6g     "Bacchanal Buffet"    The Strip
# 69993   K7lWdNUhCbcnEvI0NhGewg         "Wicked Spoon"    The Strip
# 81212   cYwJA2A6I12KNkm2rtXd5g  "Gordon Ramsay BurGR"    The Strip
# 139699  DkYS3arLOhA8si5uUEmHOw     "Earl of Sandwich"    The Strip
#
#                         address       city state postal_code   latitude  \
# 97944   "3655 Las Vegas Blvd S"  Las Vegas    NV       89109  36.112827
# 119907  "3570 S Las Vegas Blvd"  Las Vegas    NV       89109  36.116113
# 69993   "3708 Las Vegas Blvd S"  Las Vegas    NV       89109  36.109538
# 81212   "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.110724
# 139699  "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.108228
#
#          longitude  stars  review_count  is_open  \
# 97944  -115.172581    4.0          7361        1
# 119907 -115.176222    4.0          7009        1
# 69993  -115.176170    3.5          5950        1
# 81212  -115.172169    4.0          5447        0
# 139699 -115.171869    4.5          4869        1
#
#                                                categories  Restaurants  \
# 97944   French;Steakhouses;Restaurants;Breakfast & Brunch         True
# 119907  Sandwiches;Buffets;Restaurants;Breakfast & Bru...         True
# 69993              Buffets;Breakfast & Brunch;Restaurants         True
# 81212          American (Traditional);Burgers;Restaurants         True
# 139699  Caterers;Sandwiches;Restaurants;Food Delivery ...         True
#
#         cluster
# 97944         1
# 119907        1
# 69993         1
# 81212         1
# 139699        1

# %%
top_restaurants_order = top_restaurants.sort_values(by=['review_count', 'stars'], ascending=False)
top_restaurants_order.head()
# Out:
#                    business_id                   name neighborhood  \
# 97944   4JNXUYY8wbaaDmk3BPzlWw         "Mon Ami Gabi"    The Strip
# 119907  RESDUcs7fIiihp38-d6_6g     "Bacchanal Buffet"    The Strip
# 69993   K7lWdNUhCbcnEvI0NhGewg         "Wicked Spoon"    The Strip
# 81212   cYwJA2A6I12KNkm2rtXd5g  "Gordon Ramsay BurGR"    The Strip
# 139699  DkYS3arLOhA8si5uUEmHOw     "Earl of Sandwich"    The Strip
#
#                         address       city state postal_code   latitude  \
# 97944   "3655 Las Vegas Blvd S"  Las Vegas    NV       89109  36.112827
# 119907  "3570 S Las Vegas Blvd"  Las Vegas    NV       89109  36.116113
# 69993   "3708 Las Vegas Blvd S"  Las Vegas    NV       89109  36.109538
# 81212   "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.110724
# 139699  "3667 Las Vegas Blvd S"  Las Vegas    NV       89109  36.108228
#
#          longitude  stars  review_count  is_open  \
# 97944  -115.172581    4.0          7361        1
# 119907 -115.176222    4.0          7009        1
# 69993  -115.176170    3.5          5950        1
# 81212  -115.172169    4.0          5447        0
# 139699 -115.171869    4.5          4869        1
#
#                                                categories  Restaurants  \
# 97944   French;Steakhouses;Restaurants;Breakfast & Brunch         True
# 119907  Sandwiches;Buffets;Restaurants;Breakfast & Bru...         True
# 69993              Buffets;Breakfast & Brunch;Restaurants         True
# 81212          American (Traditional);Burgers;Restaurants         True
# 139699  Caterers;Sandwiches;Restaurants;Food Delivery ...         True
#
#         cluster
# 97944         1
# 119907        1
# 69993         1
# 81212         1
# 139699        1

# %% [markdown]
# **Function for recommendation based on geo location**

# %%
def recommend_restaurants(df, longitude, latitude):
    # Predict the cluster for longitude and latitude provided
    cluster = kmeans.predict(np.array([longitude,latitude]).reshape(1,-1))[0]
    print(cluster)
   
    # Get the best restaurant in this cluster
    return  df[df['cluster']==cluster].iloc[0:30][['name','city','stars', 'latitude','longitude','address','categories']]

# %% [markdown]
# **Connecting to Mongo DB**

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient("34.83.108.19",27017)
db = client['gradHousing']

# %% [markdown]
# **Recommendation for North Carolina**

# %%
north_carolina=recommend_restaurants(top_restaurants,35.152725,-80.827953)
north_carolina_list=[]
north_carolina_list=north_carolina.values.tolist()
north_carolina
# Out:
# 3
#                                          name       city  stars   latitude  \
# 144620         "The Cowfish Sushi Burger Bar"  Charlotte    4.0  35.152725
# 115558        "Amélie's French Bakery & Café"  Charlotte    4.0  35.241145
# 73231                    "Midwood Smokehouse"  Charlotte    4.5  35.221004
# 92689                          "Tupelo Honey"  Charlotte    4.0  35.211178
# 43961                        "Cabo Fish Taco"  Charlotte    4.0  35.247251
# 13417                     "Soul Gastrolounge"  Charlotte    4.0  35.220214
# 173858               "Pinky's Westside Grill"  Charlotte    4.0  35.229054
# 10315                   "Mert's Heart & Soul"  Charlotte    3.5  35.227318
# 134627                         "Viva Chicken"  Charlotte    4.5  35.213421
# 122612                            "Futo Buta"  Charlotte    4.0  35.215379
# 133689             "Sabor Latin Street Grill"  Charlotte    4.5  35.216213
# 87663                        "Midnight Diner"  Charlotte    4.0  35.219500
# 41761                           "Cajun Queen"  Charlotte    4.0  35.214537
# 161315                             "300 East"  Charlotte    4.0  35.210553
# 128736                "Good Food on Montford"  Charlotte    4.5  35.170949
# 118454                              "5Church"  Charlotte    3.5  35.228362
# 123316                  "Terrace Restaurants"  Charlotte    4.0  35.152437
# 153726              "Zada Jane's Corner Cafe"  Charlotte    3.5  35.220530
# 46234                            "Fahrenheit"  Charlotte    3.0  35.222585
# 113701                     "Dandelion Market"  Charlotte    4.0  35.228669
# 58129               "Seoul Food Meat Company"  Charlotte    4.0  35.219204
# 154403               "Paco's Tacos & Tequila"  Charlotte    4.0  35.156233
# 147882                        "Heist Brewery"  Charlotte    3.5  35.245468
# 155633                   "Basil Thai Cuisine"  Charlotte    3.5  35.228886
# 140986                             "Ru San's"  Charlotte    4.0  35.197738
# 49261   "The Flying Biscuit Cafe - Charlotte"  Charlotte    4.0  35.174229
# 87591                     "Bang Bang Burgers"  Charlotte    4.5  35.212371
# 34996                    "The King's Kitchen"  Charlotte    4.0  35.227757
# 151092         "Cowbell Burger & Whiskey Bar"  Charlotte    4.0  35.228577
# 162919          "McKoy's Smokehouse & Saloon"  Charlotte    4.0  35.178768
#
#         longitude                          address  \
# 144620 -80.827953        "4310 Sharon Rd, Ste X05"
# 115558 -80.812057    "2424 N Davidson St, Ste 102"
# 73231  -80.814875               "1401 Central Ave"
# 92689  -80.858604                "1820 South Blvd"
# 43961  -80.805827             "3201 N Davidson St"
# 13417  -80.813368             "1500-B Central Ave"
# 173858 -80.867370             "1600 W Morehead St"
# 10315  -80.840130               "214 N College St"
# 134627 -80.826022             "1617 Elizabeth Ave"
# 122612 -80.855443                   "222 Bland St"
# 133689 -80.821690               "415 Hawthorne Ln"
# 87663  -80.852195              "115 E Carson Blvd"
# 41761  -80.821133                  "1800 E 7th St"
# 161315 -80.856673                  "300 East Blvd"
# 128736 -80.848325               "1701 Montford Dr"
# 118454 -80.842779          "127 N Tryon St, Ste 8"
# 123316 -80.839518  "4625 Piedmont Row Dr, Ste 105"
# 153726 -80.811841               "1601 Central Ave"
# 46234  -80.841094              "222 S Caldwell St"
# 113701 -80.842410                   "118 W 5th St"
# 58129  -80.857698        "1400 S Church St, Ste A"
# 154403 -80.830848             "6401 Morrison Blvd"
# 147882 -80.809440    "2909 N Davidson St, Ste 200"
# 155633 -80.842666                "210 N Church St"
# 140986 -80.852719                   "2440 Park Rd"
# 49261  -80.848142                   "4241 Park Rd"
# 87591  -80.817164           "2001 E 7th St, Ste D"
# 34996  -80.844322                 "129 W Trade St"
# 151092 -80.842514       "201 N Tryon St, Ste 1010"
# 162919 -80.880019          "4630 Old Pineville Rd"
#
#                                                categories
# 144620        Restaurants;Asian Fusion;Burgers;Sushi Bars
# 115558  Restaurants;Food;Patisserie/Cake Shop;Coffee &...
# 73231   Smokehouse;Pizza;Food;Restaurants;Barbeque;Ame...
# 92689   Breakfast & Brunch;Southern;Restaurants;Americ...
# 43961          Latin American;Mexican;Restaurants;Seafood
# 13417       Nightlife;Restaurants;Tapas Bars;Lounges;Bars
# 173858  American (Traditional);Restaurants;Vegetarian;...
# 10315   Southern;Soul Food;Restaurants;Breakfast & Brunch
# 134627                               Peruvian;Restaurants
# 122612            Asian Fusion;Ramen;Japanese;Restaurants
# 133689  Street Vendors;Restaurants;Food;Mexican;Latin ...
# 87663   Diners;Breakfast & Brunch;Restaurants;American...
# 41761   Nightlife;Jazz & Blues;Restaurants;Cajun/Creol...
# 161315  Bars;Breakfast & Brunch;Wine Bars;Nightlife;Am...
# 128736  Tapas Bars;Cocktail Bars;Tapas/Small Plates;Am...
# 118454  Restaurants;American (New);Food;Desserts;Cockt...
# 123316  Comfort Food;Food;Breakfast & Brunch;American ...
# 153726  Breakfast & Brunch;Sandwiches;American (New);S...
# 46234              American (New);Pizza;Salad;Restaurants
# 113701  Bars;Nightlife;American (New);Tapas/Small Plat...
# 58129   Asian Fusion;Restaurants;Barbeque;Korean;Chick...
# 154403   Tex-Mex;Restaurants;Bars;Mexican;Nightlife;Tacos
# 147882  Restaurants;Breweries;Nightlife;American (New)...
# 155633                Vegetarian;Thai;Restaurants;Seafood
# 140986                    Sushi Bars;Japanese;Restaurants
# 49261   American (New);Southern;Restaurants;Soul Food;...
# 87591                  Restaurants;Burgers;American (New)
# 34996   Southern;Restaurants;Food;American (Traditiona...
# 151092    Bars;Nightlife;Restaurants;Burgers;Whiskey Bars
# 162919        Barbeque;Southern;Chicken Wings;Restaurants

# %% [markdown]
# **Recommendation for Illinois**

# %%
illinois=recommend_restaurants(top_restaurants,40.1105875,-88.2072697)
illinois_list=[]
illinois_list=illinois.values.tolist()
illinois
illinois = df_restaurants[df_restaurants.state == 'IL'].iloc[0:30][['name','city','stars', 'latitude','longitude','address','categories']].sort_values(by=[ 'stars'], ascending=False)
# Out:
#                                  name          city  stars   latitude  \
# 1991          "JP Cool's Bar & Grill"     Mansfield    5.0  40.211684
# 9722                   "Pies by Inge"    Monticello    5.0  40.025702
# 7397                         "Arby's"     Champaign    4.5  40.131140
# 8897                  "C & C Kitchen"       Rantoul    4.5  40.310654
# 4853                   "Proud Marys'"       Tuscola    4.5  39.791242
# 190              "Zorba's Restaurant"     Champaign    4.0  40.110085
# 1341                          "I Wok"         Savoy    4.0  40.059012
# 8427                        "El Toro"        Urbana    3.5  40.123643
# 6352               "Silver Mine Subs"     Champaign    3.5  40.108174
# 5752               "Big Grove Tavern"     Champaign    3.5  40.118381
# 3937        "Garcia's Pizza In A Pan"     Champaign    3.5  40.110515
# 3898              "A Plus VIP Lounge"        Urbana    3.5  40.112708
# 3014              "Milo's Restaurant"        Urbana    3.5  40.083853
# 9505                        "El Toro"  Saint Joseph    3.5  40.111228
# 416                          "K-Bowl"     Champaign    3.5  40.109988
# 3457  "Holy Land Mediterranean Grill"     Champaign    3.5  40.122140
# 9417                         "Lacy's"        Urbana    3.0  40.112308
# 156                      "Crepe Cafe"     Champaign    3.0  40.109986
# 9493              "Hamilton Walker's"     Champaign    3.0  40.117491
# 8553            "Guido's Bar & Grill"     Champaign    3.0  40.117863
# 7024             "Pizza King & Video"  Saint Joseph    3.0  40.111620
# 7989              "The Great Impasta"        Urbana    3.0  40.111242
# 7917                "Monical's Pizza"       Mahomet    3.0  40.192108
# 7775               "McAlister's Deli"     Champaign    3.0  40.141668
# 6825             "Outback Steakhouse"     Champaign    3.0  40.144995
# 9210                     "Spicy Tang"     Champaign    2.5  40.110748
# 9688                         "Subway"     Champaign    2.5  40.110630
# 9941                           "Miko"        Urbana    2.5  40.116124
# 2772                        "Wendy's"     Champaign    1.5  40.090882
# 2574                    "Burger King"     Champaign    1.5  40.142102
#
#       longitude                  address  \
# 1991 -88.505562      "14 N Jefferson St"
# 9722 -88.573161    "212 W Washington St"
# 7397 -88.257562    "1502 N Prospect Ave"
# 8897 -88.158583     "107 E Sangamon Ave"
# 4853 -88.273007    "1003 E Southline Rd"
# 190  -88.229304         "627 E Green St"
# 1341 -88.252238          "113 Calvin St"
# 8427 -88.200627  "1104 N Cunningham Ave"
# 6352 -88.229693        "612 E Daniel St"
# 5752 -88.242996   "1 E Main St, Ste 101"
# 3937 -88.237634         "108 E Green St"
# 3898 -88.209562          "214 W Main St"
# 3014 -88.190494          "2870 Philo Rd"
# 9505 -88.041494       "221 E Lincoln St"
# 416  -88.240506          "39 E Green St"
# 3457 -88.243543          "705 N Neil St"
# 9417 -88.208311          "119 W Main St"
# 156  -88.233777  "313 E Green St, Ste 5"
# 9493 -88.243875          "201 N Neil St"
# 8553 -88.243301            "2 E Main St"
# 7024 -88.041927          "103 N Main St"
# 7989 -88.207212   "156 C Lincoln Square"
# 7917 -88.400262       "114 S Lombard St"
# 7775 -88.250360     "421 Town Center Rd"
# 6825 -88.257184    "2402 N Prospect Ave"
# 9210 -88.230632           "607 S 6th St"
# 9688 -88.229631         "616 E Green St"
# 9941 -88.211810   "407 W University Ave"
# 2772 -88.246301         "1905 S Neil St"
# 2574 -88.257165    "2110 N Prospect Ave"
#
#                                              categories
# 1991  Food;Nightlife;Restaurants;Beer;Wine & Spirits...
# 9722        Desserts;Cupcakes;Restaurants;Bakeries;Food
# 7397                   Fast Food;Sandwiches;Restaurants
# 8897  Coffee & Tea;Food;Restaurants;Sandwiches;Break...
# 4853  Bars;Restaurants;Nightlife;American (Traditional)
# 190               Restaurants;Greek;Salad;Mediterranean
# 1341                                Restaurants;Chinese
# 8427                                Restaurants;Mexican
# 6352                             Restaurants;Sandwiches
# 5752  Bars;Breakfast & Brunch;Restaurants;Pubs;Gastr...
# 3937                                  Pizza;Restaurants
# 3898  Restaurants;Venues & Event Spaces;Cafes;Lounge...
# 3014                         American (New);Restaurants
# 9505                                Restaurants;Mexican
# 416                     Restaurants;Asian Fusion;Korean
# 3457   Restaurants;Mediterranean;Middle Eastern;Turkish
# 9417                               Barbeque;Restaurants
# 156                               Restaurants;Creperies
# 9493  Bars;Restaurants;Nightlife;Food;Seafood;Steakh...
# 8553  Bars;Nightlife;American (Traditional);Restaurants
# 7024  Videos & Video Game Rental;Books;Mags;Music & ...
# 7989                                Restaurants;Italian
# 7917                          Italian;Pizza;Restaurants
# 7775            Food;Delis;Restaurants;Sandwiches;Salad
# 6825                            Restaurants;Steakhouses
# 9210                           Asian Fusion;Restaurants
# 9688                   Restaurants;Sandwiches;Fast Food
# 9941  Restaurants;Korean;Sushi Bars;Vietnamese;Japanese
# 2772                      Burgers;Restaurants;Fast Food
# 2574                      Burgers;Restaurants;Fast Food

# %% [markdown]
# **Recommendation for Arizona**

# %%
arizona=recommend_restaurants(top_restaurants,-111.928001,32.424564)
arizona_list=[]
arizona_list=arizona.values.tolist()
arizona
# Out:
# 2
#                                    name        city  stars   latitude  \
# 148820                "Pizzeria Bianco"     Phoenix    4.0  33.449160
# 152492             "Four Peaks Brewing"       Tempe    4.5  33.419568
# 100969                        "Bobby Q"     Phoenix    4.5  33.561085
# 115632                    "Lux Central"     Phoenix    4.5  33.500597
# 130242           "Rehab Burger Therapy"  Scottsdale    4.5  33.491503
# 171047                           "Cibo"     Phoenix    4.5  33.454960
# 831                      "La Santisima"     Phoenix    4.0  33.469201
# 41036            "The Mission Old Town"  Scottsdale    4.0  33.492287
# 163111               "Joe's Farm Grill"     Gilbert    4.0  33.321824
# 157852           "Citizen Public House"  Scottsdale    4.5  33.498210
# 39519            "The Arrogant Butcher"     Phoenix    4.0  33.447392
# 82162            "Matt's Big Breakfast"     Phoenix    4.0  33.457448
# 27729       "Lo-Lo's Chicken & Waffles"     Phoenix    4.0  33.435372
# 64807                   "Cornish Pasty"       Tempe    4.5  33.423059
# 53091                     "Olive & Ivy"  Scottsdale    4.0  33.500191
# 153363                "Little Miss BBQ"     Phoenix    5.0  33.421808
# 49394                   "Chino Bandido"     Phoenix    4.0  33.626831
# 115327         "St. Francis Restaurant"     Phoenix    4.0  33.509031
# 58260                     "Barrio Café"     Phoenix    4.0  33.479016
# 92824               "Chelsea's Kitchen"     Phoenix    4.0  33.511254
# 105518               "Culinary Dropout"  Scottsdale    4.0  33.502006
# 71877                 "Postino Arcadia"     Phoenix    4.5  33.502111
# 40496                  "Liberty Market"     Gilbert    4.0  33.354768
# 140763     "Pappadeaux Seafood Kitchen"     Phoenix    4.0  33.587654
# 116943         "SanTan Brewing Company"    Chandler    4.0  33.303234
# 34144        "Original Breakfast House"     Phoenix    4.5  33.610804
# 7834                       "Taco Guild"     Phoenix    4.0  33.487747
# 11124             "Snooze An AM Eatery"     Phoenix    4.0  33.508204
# 160309                     "The Parlor"     Phoenix    4.0  33.509446
# 103789  "Green New American Vegetarian"       Tempe    4.5  33.453787
#
#          longitude                                           address  \
# 148820 -112.065635                                  "623 E Adams St"
# 152492 -111.916097                          "1340 E 8th St, Ste 104"
# 100969 -112.115747                                 "8501 N 27th Ave"
# 115632 -112.074237                              "4400 N Central Ave"
# 130242 -111.925627                                   "7210 E 2nd St"
# 171047 -112.079908                                   "603 N 5th Ave"
# 831    -112.047393                                  "1919 N 16th St"
# 41036  -111.924273                                "3815 N Brown Ave"
# 163111 -111.726057                           "3000 E Ray Rd, Bldg 1"
# 157852 -111.927963                           "7111 E 5th Ave, Ste E"
# 39519  -112.072831                       "2 E Jefferson St, Ste 150"
# 82162  -112.072295                                    "825 N 1st St"
# 27729  -112.073970                              "1220 S Central Ave"
# 64807  -111.951843                             "960 W University Dr"
# 53091  -111.928395                    "7135 E Camelback Rd, Ste 195"
# 153363 -111.989174                            "4301 E University Dr"
# 49394  -112.100300                         "15414 N 19th Ave, Ste K"
# 115327 -112.071295                              "111 E Camelback Rd"
# 58260  -112.047989                                  "2814 N 16th St"
# 92824  -111.995652                                  "5040 N 40th St"
# 105518 -111.928296                    "7135 E Camelback Rd, Ste 125"
# 71877  -111.996339                             "3939 E Campbell Ave"
# 40496  -111.789833                                "230 N Gilbert Rd"
# 140763 -112.115796                        "11051 N Black Canyon Hwy"
# 116943 -111.842529                               "8 S San Marcos Pl"
# 34144  -112.012836                                 "13623 N 32nd St"
# 7834   -112.065665                                 "546 E Osborn Rd"
# 11124  -112.037033  "2045 E Camelback Rd, Ste A17, Town and Country"
# 160309 -112.040395                             "1916 E Camelback Rd"
# 103789 -111.927166                            "2240 N Scottsdale Rd"
#
#                                                categories
# 148820         Restaurants;Salad;Pizza;Italian;Sandwiches
# 152492  American (New);Sandwiches;Burgers;Nightlife;Ba...
# 100969  Caterers;American (New);Restaurants;Event Plan...
# 115632  Breakfast & Brunch;American (New);Bakeries;Res...
# 130242  Restaurants;Sandwiches;Bars;Nightlife;Burgers;...
# 171047               Sandwiches;Pizza;Restaurants;Italian
# 831     Vegetarian;Nightlife;Mexican;Bars;Vegan;Restau...
# 41036   Restaurants;Bars;Nightlife;Mexican;Latin American
# 163111  Italian;American (Traditional);Pizza;Restauran...
# 157852  Salad;Cocktail Bars;Bars;Gastropubs;American (...
# 39519   Seafood;Bars;Nightlife;American (Traditional);...
# 82162                      Restaurants;Breakfast & Brunch
# 27729              Soul Food;Restaurants;Southern;Waffles
# 64807   Caterers;Bars;Restaurants;British;Pubs;Event P...
# 53091   Mediterranean;Restaurants;American (Traditiona...
# 153363                               Restaurants;Barbeque
# 49394   Asian Fusion;Chinese;Szechuan;Mexican;Restaurants
# 115327     Restaurants;Salad;Food;Desserts;American (New)
# 58260   Sandwiches;Mexican;Breakfast & Brunch;Cafes;Re...
# 92824   Breakfast & Brunch;Restaurants;American (Tradi...
# 105518  Music Venues;Venues & Event Spaces;American (N...
# 71877   Bars;Breakfast & Brunch;Italian;Restaurants;Ni...
# 40496   Restaurants;Coffee & Tea;Breakfast & Brunch;Fo...
# 140763                   Restaurants;Cajun/Creole;Seafood
# 116943  Wine Bars;American (New);American (Traditional...
# 34144   Cafes;Restaurants;Seafood;Breakfast & Brunch;B...
# 7834    Mexican;Bars;Nightlife;Restaurants;Cocktail Ba...
# 11124   Breakfast & Brunch;Coffee & Tea;Food;Restauran...
# 160309         Sandwiches;Salad;Italian;Pizza;Restaurants
# 103789           Vegan;Vegetarian;Gluten-Free;Restaurants

# %% [markdown]
# **Recommendation for Colorado**

# %%
colorado=recommend_restaurants(top_restaurants,-8.392635,51.812438)
colorado_list=[]
colorado_list=arizona.values.tolist()
colorado
# Out:
#                               name         city  stars   latitude  longitude  \
# 898   "The Abbey Bar & Restaurant"  Main Street    3.0  51.812438  -8.392635
# 6307             "Sage Restaurant"  Main Street    4.5  51.916151  -8.174059
#
#                            address                        categories
# 898     "Main Street, Carrigaline"  Irish;Bars;Nightlife;Restaurants
# 6307  "No 8 Main Street, Midleton"                 Irish;Restaurants

# %% [markdown]
# **Recommendation for LasVegas**

# %%
lasvegas=recommend_restaurants(top_restaurants,-115.287451,36.159483)
lasvegas_list=[]
lasvegas_list=arizona.values.tolist()
lasvegas
# Out:
#                                       name             city  stars   latitude  \
# 538                           "Baja Fresh"        Las Vegas    5.0  36.159483
# 778                   "The Hummus Factory"        Las Vegas    4.5  36.143204
# 721                       "The Blacc Boxx"  North Las Vegas    4.5  36.196983
# 691                    "Mexicali Raspados"        Las Vegas    4.5  36.100688
# 177                 "Geebee's Bar & Grill"        Las Vegas    4.5  36.034244
# 274                     "Trattoria Italia"        Las Vegas    4.5  36.010086
# 303                   "Cancun Bar & Grill"        Las Vegas    4.5  36.098632
# 366                              "Kinthai"        Las Vegas    4.5  36.144023
# 52               "Flight Deck Bar & Grill"        Las Vegas    4.0  36.066914
# 428   "Rise & Shine - A Steak & Egg Place"        Henderson    4.0  36.024323
# 133  "Divine Cafe at the Springs Preserve"        Las Vegas    4.0  36.170706
# 789                          "Sierra Gold"        Las Vegas    3.5  36.070325
# 675                         "Del Mar Deli"        Las Vegas    3.5  36.011541
# 792                   "Jersey Mike's Subs"        Henderson    3.5  36.000508
# 379           "North Forty Saloon and BBQ"        Las Vegas    3.5  36.271838
# 629                   "Christy Candy Shop"        Las Vegas    3.0  36.124902
# 642                               "Makino"        Las Vegas    3.0  36.015136
# 145                               "Subway"        Las Vegas    3.0  36.112895
# 54                             "GameWorks"        Las Vegas    3.0  36.068259
# 433        "The Bass Cafe Grill & Terrace"        Las Vegas    2.5  36.140925
# 53                                "Subway"        Las Vegas    2.5  36.064652
# 621                        "Panda Express"        Las Vegas    2.5  36.122084
# 632                           "Jack's Pub"        Las Vegas    2.5  36.144440
# 772      "Carnival World & Seafood Buffet"        Las Vegas    2.5  36.117506
# 409                          "Burger King"        Las Vegas    2.0  36.150372
# 695                           "McDonald's"        Las Vegas    2.0  36.098909
# 122                           "McDonald's"        Las Vegas    2.0  36.130013
# 737                       "Tootie's Place"        Las Vegas    2.0  36.068003
# 497                            "Pizza Hut"        Las Vegas    2.0  36.238059
# 91                        "Cafe Mastrioni"        Las Vegas    1.5  36.111057
#
#       longitude                                        address  \
# 538 -115.287451              "8780 W Charleston Blvd, Ste 100"
# 778 -115.262866                   "7875 W Sahara Ave, Ste 101"
# 721 -115.180376                        "3011 W Lake Mead Blvd"
# 691 -115.101083                              "4865 S Pecos Rd"
# 177 -115.171409                        "8560 Las Vegas Blvd S"
# 274 -115.118656                  "9905 S Eastern Ave, Ste 140"
# 303 -115.136079                 "5006 S Maryland Pkwy, Ste 17"
# 366 -115.195896                            "4105 W Sahara Ave"
# 52  -115.170848                        "6730 S Las Vegas Blvd"
# 428 -115.062857                          "75 S Valle Verde Dr"
# 133 -115.190288                       "333 S Valley View Blvd"
# 789 -115.224952                            "6515 S Jones Blvd"
# 675 -115.175896                        "9777 Las Vegas Blvd S"
# 792 -115.105592                          "10520 South Eastern"
# 379 -115.263279                  "5990 Centennial Center Blvd"
# 629 -115.134710                         "3542 S Maryland Pkwy"
# 642 -115.118473                           "9570 S Eastern Ave"
# 145 -115.062353                             "5111 Boulder Hwy"
# 54  -115.178877               "6587 Las Vegas Blvd S, Ste 171"
# 433 -115.142887                                "900 Karen Ave"
# 53  -115.118954                  "6889 S Eastern Ave, Ste 101"
# 621 -115.168032                        "3355 Las Vegas Blvd S"
# 632 -115.174439                            "2416 W Sahara Ave"
# 772 -115.188844                           "3700 W Flamingo Rd"
# 409 -115.153558                        "1736 Las Vegas Blvd S"
# 695 -115.175557  "Excalibur Food Court, 3850 Las Vegas Blvd S"
# 122 -115.109310                         "3020 E Desert Inn Rd"
# 737 -115.176446                        "6601 Las Vegas Blvd S"
# 497 -115.210341                           "4945 W. Craig Road"
# 91  -115.241688                "4250 S Rainbow Blvd, Ste 1007"
#
#                                             categories
# 538                                Restaurants;Mexican
# 778  Event Planning & Services;Caterers;Burgers;Gre...
# 721  Sandwiches;Bakeries;Food;Chicken Wings;Cafes;R...
# 691  Restaurants;Ice Cream & Frozen Yogurt;Shaved I...
# 177                 Restaurants;American (Traditional)
# 274                  Seafood;Italian;Pizza;Restaurants
# 303  Karaoke;Bars;Mexican;Restaurants;Nightlife;Dan...
# 366                                   Restaurants;Thai
# 52   Nightlife;Bars;Barbeque;Sports Bars;American (...
# 428                     Breakfast & Brunch;Restaurants
# 133  Restaurants;Cafes;American (New);Bars;Nightlif...
# 789  American (New);Restaurants;Pubs;Nightlife;Spor...
# 675    Delis;Sandwiches;Restaurants;Breakfast & Brunch
# 792             Fast Food;Delis;Restaurants;Sandwiches
# 379  Dance Clubs;Nightlife;Restaurants;Barbeque;Ame...
# 629  Food;Restaurants;Specialty Food;Mexican;Candy ...
# 642                               Restaurants;Japanese
# 145                   Sandwiches;Restaurants;Fast Food
# 54   Arcades;Arts & Entertainment;Gastropubs;Restau...
# 433  Restaurants;American (Traditional);Food;Coffee...
# 53                    Fast Food;Restaurants;Sandwiches
# 621                      Restaurants;Fast Food;Chinese
# 632              Nightlife;Pubs;Restaurants;Irish;Bars
# 772                        Buffets;Seafood;Restaurants
# 409                                Burgers;Restaurants
# 695                      Burgers;Fast Food;Restaurants
# 122                      Restaurants;Fast Food;Burgers
# 737                    Restaurants;Fast Food;Creperies
# 497                                  Restaurants;Pizza
# 91                                 Italian;Restaurants

# %% [markdown]
# **Pushing the Data to DataBase**

# %%
for i in range(len(north_carolina_list)):
    article = {"State": "North Carolina",
            "Name": north_carolina_list[i][0],
            "City": north_carolina_list[i][1],
             "Rating":north_carolina_list[i][2], 
             "address":north_carolina_list[i][5],
             "category":north_carolina_list[i][6],
             "loc":{"type":"Point",
                     "coordinates": [north_carolina_list[i][4],north_carolina_list[i][3]]},}
    articles = db.recommendations
    result = articles.insert_one(article)

# %%
for i in range(len(lasvegas_list)):
    article = {"State": "LasVegas",
            "Name": lasvegas_list[i][0],
            "City": lasvegas_list[i][1],
            "Rating":lasvegas_list[i][2], 
            "address":lasvegas_list[i][5],
            "category":lasvegas_list[i][6],
             "loc": {"type":"Point",
                     "coordinates":[lasvegas_list[i][4],lasvegas_list[i][3]]},}
    articles = db.recommendations
    result = articles.insert_one(article)

# %%
for i in range(len(arizona_list)):
    article = {"State": "Arizona",
            "Name": arizona_list[i][0],
            "City": arizona_list[i][1],
             "Rating":arizona_list[i][2],
             "address":arizona_list[i][5],
             "category":arizona_list[i][6],  
             "loc":{"type":"Point",
                     "coordinates": [arizona_list[i][4],arizona_list[i][3]]},}
    articles = db.recommendations
    result = articles.insert_one(article)

# %%
for i in range(len(illinois_list)):
    article = {"State": "Illinois",
            "Name": illinois_list[i][0],
            "City": illinois_list[i][1],
             "Rating":illinois_list[i][2], 
            "address":illinois_list[i][5],
             "category":illinois_list[i][6],
             "loc":{"type":"Point",
                     "coordinates": [illinois_list[i][4],illinois_list[i][3]]},}
    articles = db.recommendations
    result = articles.insert_one(article)

# %%
for i in range(len(colorado_list)):
    article = {"State": "Colorado",
            "Name": colorado_list[i][0],
            "City": colorado_list[i][1],
            "Rating":colorado_list[i][2],
            "address":colorado_list[i][5],
             "category":colorado_list[i][6],
             "loc":{"type":"Point",
                     "coordinates": [colorado_list[i][4],colorado_list[i][3]]},}
    articles = db.recommendations
    result = articles.insert_one(article)

# %% [markdown]
# **Validation of Recommendation**

# %%
# illinois_list=[]
# illinois_list=illinois.values.tolist()
# illinois

# lasvegas = df_restaurants[df_restaurants.state == 'NV'].iloc[0:30][['name','city','stars', 'latitude','longitude','address','categories']].sort_values(by=[ 'stars'], ascending=False)

# lasvegas_list=[]
# lasvegas_list=lasvegas.values.tolist()
# lasvegas



# colorado = df_restaurants[df_restaurants.state == 'CO'].iloc[0:2][['name','city','stars', 'latitude','longitude','address','categories']]
# colorado_list=[]
# colorado_list=colorado.values.tolist()
# colorado
